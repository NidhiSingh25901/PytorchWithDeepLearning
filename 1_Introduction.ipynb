# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhiSingh25901/PytorchWithDeepLearning/blob/main/1_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! I am excited to learn Python Programming Language")
# Out:
# Hello! I am excited to learn Python Programming Language

# %%
# !nvidia-smi
# Out:
# Sun Nov  9 05:45:28 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(torch.__version__)
# Out:
# 2.8.0+cu126

# %%
#Introduction to tensor - tensor is a way to represent numeric data
# Pytorch tensor is creates using torch.tensor()

#creating scalar using tensor
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
scalar.ndim
# Out:
# 0

# %%
scalar.item()
# Out:
# 7

# %%
#Creating vector using tensor
vector = torch.tensor([7,7])
vector
# Out:
# tensor([7, 7])

# %%
vector.ndim
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %%
#matrix using tensor
matrix = torch.tensor([[7,8],
                       [9,10]])
matrix
# Out:
# tensor([[ 7,  8],
#         [ 9, 10]])

# %%
matrix.ndim
# Out:
# 2

# %%
matrix[1]
# Out:
# tensor([ 9, 10])

# %%
matrix.shape
# Out:
# torch.Size([2, 2])

# %%
tensor = torch.tensor([[[1,2,3],
                        [3,4,5,],
                        [6,7,8]]])
tensor
# Out:
# tensor([[[1, 2, 3],
#          [3, 4, 5],
#          [6, 7, 8]]])

# %%
tensor.ndim
# Out:
# 3

# %%
tensor.shape
# Out:
# torch.Size([1, 3, 3])

# %%
#creating a random tensor of size (3,4)
random_tensor = torch.rand(3,4)
random_tensor
# Out:
# tensor([[0.3660, 0.2867, 0.9171, 0.4563],
#         [0.0834, 0.7682, 0.2273, 0.9121],
#         [0.8748, 0.1332, 0.6220, 0.5666]])

# %%
random_tensor.ndim
# Out:
# 2
